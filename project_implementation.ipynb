# %%
#UTILS
# !pip install visdom
import random
import time
import datetime
import sys

from torch.autograd import Variable
import torch
# from visdom import Visdom
import numpy as np

def print_network(net):
    num_params = 0
    for param in net.parameters():
        num_params += param.numel()
    print(net)
    print('Total number of parameters: %d' % num_params)

def tensor2image(tensor):
    image = 127.5*(tensor[0].cpu().float().numpy() + 1.0)
    if image.shape[0] == 1:
        image = np.tile(image, (3,1,1))
    return image.astype(np.uint8)

# class Logger():
#     def __init__(self, n_epochs, batches_epoch):
#         self.viz = Visdom()
#         self.n_epochs = n_epochs
#         self.batches_epoch = batches_epoch
#         self.epoch = 1
#         self.batch = 1
#         self.prev_time = time.time()
#         self.mean_period = 0
#         self.losses = {}
#         self.loss_windows = {}
#         self.image_windows = {}


    def log(self, losses=None, images=None):
        self.mean_period += (time.time() - self.prev_time)
        self.prev_time = time.time()

        sys.stdout.write('\rEpoch %03d/%03d [%04d/%04d] -- ' % (self.epoch, self.n_epochs, self.batch, self.batches_epoch))

        for i, loss_name in enumerate(losses.keys()):
            if loss_name not in self.losses:
                self.losses[loss_name] = losses[loss_name].data[0]
            else:
                self.losses[loss_name] += losses[loss_name].data[0]

            if (i+1) == len(losses.keys()):
                sys.stdout.write('%s: %.4f -- ' % (loss_name, self.losses[loss_name]/self.batch))
            else:
                sys.stdout.write('%s: %.4f | ' % (loss_name, self.losses[loss_name]/self.batch))

        batches_done = self.batches_epoch*(self.epoch - 1) + self.batch
        batches_left = self.batches_epoch*(self.n_epochs - self.epoch) + self.batches_epoch - self.batch 
        sys.stdout.write('ETA: %s' % (datetime.timedelta(seconds=batches_left*self.mean_period/batches_done)))

        # Draw images
        for image_name, tensor in images.items():
            if image_name not in self.image_windows:
                self.image_windows[image_name] = self.viz.image(tensor2image(tensor.data), opts={'title':image_name})
            else:
                self.viz.image(tensor2image(tensor.data), win=self.image_windows[image_name], opts={'title':image_name})

        # End of epoch
        if (self.batch % self.batches_epoch) == 0:
            # Plot losses
            for loss_name, loss in self.losses.items():
                if loss_name not in self.loss_windows:
                    self.loss_windows[loss_name] = self.viz.line(X=np.array([self.epoch]), Y=np.array([loss/self.batch]), 
                                                                    opts={'xlabel': 'epochs', 'ylabel': loss_name, 'title': loss_name})
                else:
                    self.viz.line(X=np.array([self.epoch]), Y=np.array([loss/self.batch]), win=self.loss_windows[loss_name], update='append')
                # Reset losses for next epoch
                self.losses[loss_name] = 0.0

            self.epoch += 1
            self.batch = 1
            sys.stdout.write('\n')
        else:
            self.batch += 1

        

class ReplayBuffer():
    def __init__(self, max_size=50):
        assert (max_size > 0), 'Empty buffer or trying to create a black hole. Be careful.'
        self.max_size = max_size
        self.data = []

    def push_and_pop(self, data):
        to_return = []
        for element in data.data:
            element = torch.unsqueeze(element, 0)
            if len(self.data) < self.max_size:
                self.data.append(element)
                to_return.append(element)
            else:
                if random.uniform(0,1) > 0.5:
                    i = random.randint(0, self.max_size-1)
                    to_return.append(self.data[i].clone())
                    self.data[i] = element
                else:
                    to_return.append(element)
        return Variable(torch.cat(to_return))

class LambdaLR():
    def __init__(self, n_epochs, offset, decay_start_epoch):
        assert ((n_epochs - decay_start_epoch) > 0), "Decay must start before the training session ends!"
        self.n_epochs = n_epochs
        self.offset = offset
        self.decay_start_epoch = decay_start_epoch

    def step(self, epoch):
        return 1.0 - max(0, epoch + self.offset - self.decay_start_epoch)/(self.n_epochs - self.decay_start_epoch)

def weights_init_normal(m):
    classname = m.__class__.__name__
    if classname.find('Conv') != -1:
        torch.nn.init.normal(m.weight.data, 0.0, 0.02)
    elif classname.find('BatchNorm2d') != -1:
        torch.nn.init.normal(m.weight.data, 1.0, 0.02)
#        torch.nn.init.constant(m.bias.data, 0.0)

# %%
#DATASET

import glob
import random
import os

from torch.utils.data import Dataset
from PIL import Image
import torchvision.transforms as transforms

#A: Cloud
#B: Clear
#We want to go from A to B



class CloudClearDataset(Dataset):
    def __init__(self, root, transforms_=None, unaligned=False, mode='train'):
        self.transform = transforms.Compose(transforms_)
        self.unaligned = unaligned

        self.files_Cloud = sorted(glob.glob(os.path.join(root,'%s/Cloud' % mode) + '/*.png'))
        self.files_Clear = sorted(glob.glob(os.path.join(root,'%s/Clear' % mode) + '/*.png'))

    def __getitem__(self, index):
        item_Cloud = self.transform(Image.open(self.files_Cloud[index % len(self.files_Cloud)]))

        if self.unaligned:
            item_Clear = self.transform(Image.open(self.files_Clear[random.randint(0, len(self.files_Clear) - 1)]))
        else:
            item_Clear = self.transform(Image.open(self.files_Clear[index % len(self.files_Clear)]))

        return {'Cloud': item_Cloud, 'Clear': item_Clear}

    def __len__(self):
        return max(len(self.files_Clear), len(self.files_Clear))

# %%
#MODELS.py


import torch
import torch.nn as nn
from torch.autograd import Variable
import torch.nn.functional as F

class Generator(nn.Module):
    def __init__(self, input_nc=3, output_nc=4, ngf=64, norm_layer=nn.BatchNorm2d, use_dropout=False, n_blocks=6):
        assert(n_blocks >= 0)
        super(Generator, self).__init__()
        self.input_nc = input_nc
        self.output_nc = output_nc
        self.ngf = ngf

        model = [nn.ReflectionPad2d(3),
                 nn.Conv2d(input_nc, ngf, kernel_size=7, padding=0),
                 norm_layer(ngf),
                 nn.ReLU(True)]

        n_downsampling = 2
        for i in range(n_downsampling):
            mult = 2**i
            model += [nn.Conv2d(ngf * mult, ngf * mult * 2, kernel_size=3,
                                stride=2, padding=1),
                      norm_layer(ngf * mult * 2),
                      nn.ReLU(True)]

        mult = 2**n_downsampling
        for i in range(n_blocks):
            model += [ResnetBlock(ngf * mult, norm_layer=norm_layer, use_dropout=use_dropout)]

        for i in range(n_downsampling):
            mult = 2**(n_downsampling - i)
            model += [nn.ReflectionPad2d(1),
                      nn.Conv2d(ngf * mult, int(ngf * mult / 2),
                                kernel_size=3, stride=1),
                      norm_layer(int(ngf * mult / 2)),
                      nn.ReLU(True),
                      nn.Conv2d(int(ngf * mult / 2), int(ngf * mult / 2)*4,
                                kernel_size=1, stride=1),
                      nn.PixelShuffle(2),
                      norm_layer(int(ngf * mult / 2)),
                      nn.ReLU(True),
                     ]
        model += [nn.ReflectionPad2d(3)]
        model += [nn.Conv2d(ngf, output_nc, kernel_size=7, padding=0)]

        self.model = nn.Sequential(*model)

    def forward(self, input):
        output = self.model(input)
        attention_mask = F.sigmoid(output[:, :1])
        content_mask = output[:, 1:]
        attention_mask = attention_mask.repeat(1, 3, 1, 1)
        result = content_mask * attention_mask + input * (1 - attention_mask)

        return result, attention_mask, content_mask

class ResnetBlock(nn.Module):
    def __init__(self, dim, norm_layer, use_dropout):
        super(ResnetBlock, self).__init__()
        self.conv_block = self.build_conv_block(dim, norm_layer, use_dropout)

    def build_conv_block(self, dim, norm_layer, use_dropout):
        conv_block = [nn.ReflectionPad2d(1),
                       nn.Conv2d(dim, dim, kernel_size=3),
                       norm_layer(dim),
                       nn.ReLU(True)]
        if use_dropout:
            conv_block += [nn.Dropout(0.5)]

        conv_block += [nn.ReflectionPad2d(1),
                       nn.Conv2d(dim, dim, kernel_size=3),
                       norm_layer(dim)]

        return nn.Sequential(*conv_block)

    def forward(self, x):
        out = x + self.conv_block(x)
        return out


class Discriminator(nn.Module):
    def __init__(self):
        super(Discriminator, self).__init__()
        self.conv_tower = nn.Sequential(
            nn.Conv2d(3,   64,  4, 2),
            nn.BatchNorm2d(64),
            nn.LeakyReLU(),
            nn.Conv2d(64,  128,  4, 2),
            nn.BatchNorm2d(128),
            nn.LeakyReLU(),
            nn.Conv2d(128,  256,  4, 2),
            nn.BatchNorm2d(256),
            nn.LeakyReLU(),
            nn.Conv2d(256,  512, 4, 2),
            nn.BatchNorm2d(512),
            nn.LeakyReLU(),
            nn.Conv2d(512, 512, 4),
            nn.LeakyReLU(),
            nn.AdaptiveAvgPool2d((1, 1)),
            nn.Conv2d(512, 1, 1),
        )

    def forward(self, img):
        output = self.conv_tower(img)
        return output

# %%
#!/usr/bin/python3

import argparse
import itertools
import sys
import os

import torchvision.transforms as transforms
from torch.utils.data import DataLoader
import torch.nn as nn
from torch.autograd import Variable
from PIL import Image
import torch
import torch.optim as optim
from torch.optim import lr_scheduler
from torchvision.utils import save_image
import torchvision

# from models import Generator
# from models import Discriminator
# from utils import ReplayBuffer
# from utils import LambdaLR
# from utils import Logger
# from utils import weights_init_normal
# from utils import print_network
# from dataset import CloudClearDataset


#GLOBAL VARIABLES
epoch = 0
n_epochs = 60
batchSize = 1
dataroot = '/content/drive/MyDrive/CS-MultiMedia/AI/Project/rice_dataset/'
save_name = '/content/drive/MyDrive/CS-MultiMedia/AI/Project/Inference/'
lr = 0.0001
decay_epoch = 10
size = 512
input_nc = 3
output_nc = 3
# cuda = 
n_cpu = 8
lambda_cycle = 10
lambda_identity = 0
lambda_pixel = 1
lambda_reg = 1e-6
gan_curriculum = 10
starting_rate = 0.01
default_rate = 0.5



# parser = argparse.ArgumentParser()
# parser.add_argument('--epoch', type=int, default=0, help='starting epoch')
# parser.add_argument('--n_epochs', type=int, default=200, help='number of epochs of training')
# parser.add_argument('--batchSize', type=int, default=1, help='size of the batches')
# parser.add_argument('--dataroot', type=str, default='/content/drive/MyDrive/CS-MultiMedia/AI/Project/rice_dataset/', help='root directory of the dataset')
# parser.add_argument('--save_name', type=str, default='attentionGAN_RICE1_CloudClear')
# parser.add_argument('--lr', type=float, default=0.0001, help='initial learning rate')
# parser.add_argument('--decay_epoch', type=int, default=100, help='epoch to start linearly decaying the learning rate to 0')
# parser.add_argument('--size', type=int, default=256, help='size of the data crop (squared assumed)')
# parser.add_argument('--input_nc', type=int, default=3, help='number of channels of input data')
# parser.add_argument('--output_nc', type=int, default=3, help='number of channels of output data')
# parser.add_argument('--cuda', action='store_true', help='use GPU computation')
# parser.add_argument('--n_cpu', type=int, default=8, help='number of cpu threads to use during batch generation')
# parser.add_argument('--lambda_cycle', type=int, default=10)
# parser.add_argument('--lambda_identity', type=int, default=0)
# parser.add_argument('--lambda_pixel', type=int, default=1)
# parser.add_argument('--lambda_reg', type=float, default=1e-6)

# parser.add_argument('--gan_curriculum', type=int, default=10, help='Strong GAN loss for certain period at the beginning')
# parser.add_argument('--starting_rate', type=float, default=0.01, help='Set the lambda weight between GAN loss and Recon loss during curriculum period at the beginning. We used the 0.01 weight.')
# parser.add_argument('--default_rate', type=float, default=0.5, help='Set the lambda weight between GAN loss and Recon loss after curriculum period. We used the 0.5 weight.')

# opt = parser.parse_args()
# print(opt)

# if torch.cuda.is_available():
#     print("WARNING: You have a CUDA device, so you should probably run with --cuda")

###### Definition of variables ######
# Networks
netG_Cloud2Clear = Generator()
netG_Clear2Cloud = Generator()
netD_Cloud = Discriminator()
netD_Clear = Discriminator()

print('---------- Networks initialized -------------')
print_network(netG_Cloud2Clear)
print_network(netG_Clear2Cloud)
print_network(netD_Cloud)
print_network(netD_Clear)
print('-----------------------------------------------')

# if opt.cuda:
netG_Cloud2Clear.cuda()
netG_Clear2Cloud.cuda()
netD_Cloud.cuda()
netD_Clear.cuda()

netG_Cloud2Clear.apply(weights_init_normal)
netG_Clear2Cloud.apply(weights_init_normal)
netD_Cloud.apply(weights_init_normal)
netD_Clear.apply(weights_init_normal)

# Lossess
criterion_GAN = torch.nn.MSELoss()
criterion_cycle = torch.nn.L1Loss()
criterion_identity = torch.nn.L1Loss()

# Optimizers & LR schedulers
optimizer_G = torch.optim.Adam(itertools.chain(netG_Cloud2Clear.parameters(), netG_Clear2Cloud.parameters()),
                                lr=lr, betas=(0.5, 0.999))
optimizer_D = torch.optim.Adam(itertools.chain(netD_Cloud.parameters(), netD_Clear.parameters()),
                                lr=lr, betas=(0.5, 0.999))

lr_scheduler_G = torch.optim.lr_scheduler.LambdaLR(optimizer_G, lr_lambda=LambdaLR(n_epochs, epoch, decay_epoch).step)
lr_scheduler_D = torch.optim.lr_scheduler.LambdaLR(optimizer_D, lr_lambda=LambdaLR(n_epochs, epoch, decay_epoch).step)

# Inputs & targets memory allocation
Tensor = torch.cuda.FloatTensor #if opt.cuda else torch.Tensor
input_Cloud = Tensor(batchSize, input_nc, size, size)
input_Clear = Tensor(batchSize, output_nc, size, size)
target_real = Variable(Tensor(batchSize).fill_(1.0), requires_grad=False)
target_fake = Variable(Tensor(batchSize).fill_(0.0), requires_grad=False)

fake_Cloud_buffer = ReplayBuffer()
fake_Clear_buffer = ReplayBuffer()

# Dataset loader
transforms_ = [ transforms.RandomHorizontalFlip(),
                transforms.ToTensor(),
                transforms.Normalize([0.5,0.5,0.5], [0.5,0.5,0.5]) ]

dataloader = DataLoader(CloudClearDataset(dataroot, transforms_=transforms_, unaligned=True), 
                        batch_size=batchSize, shuffle=True, num_workers=n_cpu)

# Loss plot
# logger = Logger(n_epochs, len(dataloader)) # IT HAS AN ERROR WE HAVE TO PLOT THE LOSS LATER

###### Training ######
for epoch in range(epoch, n_epochs):
    for i, batch in enumerate(dataloader):
        # Set model input
        real_Cloud = Variable(input_Cloud.copy_(batch['Cloud']))
        real_Clear = Variable(input_Clear.copy_(batch['Clear']))

        ###### Generators A2B and B2A ######
        optimizer_G.zero_grad()

        # Identity loss
        # G_A2B(B) should equal B if real B is fed
        same_Clear, _, _ = netG_Cloud2Clear(real_Clear)
        loss_identity_Clear = criterion_identity(same_Clear, real_Clear)*lambda_identity
        # G_B2A(A) should equal A if real A is fed
        same_Cloud, _, _ = netG_Clear2Cloud(real_Cloud)
        loss_identity_Cloud = criterion_identity(same_Cloud, real_Cloud)*lambda_identity

        # GAN loss
        fake_Clear, mask_Clear, temp_Clear = netG_Cloud2Clear(real_Cloud)
        recovered_A, _, _ = netG_Clear2Cloud(fake_Clear)
        pred_fake_Clear = netD_Clear(fake_Clear)

        loss_cycle_CloudClearCloud = criterion_cycle(recovered_A, real_Cloud)
        loss_GAN_Cloud2Clear = criterion_GAN(pred_fake_Clear, target_real)
        loss_pix_Cloud = criterion_identity(fake_Clear, real_Cloud)

        fake_Cloud, mask_Cloud, temp_Cloud = netG_Clear2Cloud(real_Clear)
        recovered_B, _, _  = netG_Cloud2Clear(fake_Cloud)
        pred_fake_Cloud = netD_Cloud(fake_Cloud)

        loss_cycle_ClearCloudClear = criterion_cycle(recovered_B, real_Clear)
        loss_GAN_Clear2Cloud = criterion_GAN(pred_fake_Cloud, target_real)
        loss_pix_Clear = criterion_identity(fake_Cloud, real_Clear)

        loss_reg_Cloud = lambda_reg * (
                torch.sum(torch.abs(mask_Cloud[:, :, :, :-1] - mask_Cloud[:, :, :, 1:])) +
                torch.sum(torch.abs(mask_Cloud[:, :, :-1, :] - mask_Cloud[:, :, 1:, :])))

        loss_reg_Clear = lambda_reg * (
                torch.sum(torch.abs(mask_Clear[:, :, :, :-1] - mask_Clear[:, :, :, 1:])) +
                torch.sum(torch.abs(mask_Clear[:, :, :-1, :] - mask_Clear[:, :, 1:, :])))

        # Total loss
        if epoch < gan_curriculum:
            rate = starting_rate
            print('using curriculum gan')
        else:
            rate = default_rate
            print('using normal gan')

        loss_G = ((loss_GAN_Cloud2Clear + loss_GAN_Clear2Cloud)*0.5 + (loss_reg_Cloud + loss_reg_Clear))* (1.-rate) + ((loss_cycle_CloudClearCloud + loss_cycle_ClearCloudClear)*lambda_cycle+(loss_pix_Clear+loss_pix_Cloud)*lambda_pixel)* rate
    
        loss_G.backward()
        optimizer_G.step()
        ###################################

        optimizer_D.zero_grad()

        # Real loss
        pred_real_Cloud = netD_Cloud.forward(real_Cloud)
        loss_D_real_Cloud = criterion_GAN(pred_real_Cloud, target_real)

        # Fake loss
        fake_Cloud = fake_Cloud_buffer.push_and_pop(fake_Cloud)
        pred_fake_Cloud = netD_Cloud.forward(fake_Cloud.detach())
        loss_D_fake_Cloud = criterion_GAN(pred_fake_Cloud, target_fake)

        # Real loss
        pred_real_Clear = netD_Clear.forward(real_Clear)
        loss_D_real_Clear = criterion_GAN(pred_real_Clear, target_real)
        
        # Fake loss
        fake_Clear = fake_Clear_buffer.push_and_pop(fake_Clear)
        pred_fake_Clear = netD_Clear.forward(fake_Clear.detach())
        loss_D_fake_Clear = criterion_GAN(pred_fake_Clear, target_fake)

        # Total loss
        loss_D = (loss_D_real_Clear + loss_D_fake_Clear + loss_D_real_Cloud + loss_D_fake_Cloud)*0.25
        
        loss_D.backward()
        optimizer_D.step()

        print('Epoch [%d/%d], Batch [%d/%d], loss_D: %.4f, loss_G: %.4f' % (epoch+1, n_epochs,i+1, len(dataloader), loss_D.data, loss_G.data)) 
        print('loss_GAN_Cloud2Clear: %.4f, loss_GAN_Clear2Cloud: %.4f, loss_cycle_CloudClearCloud: %.4f, loss_cycle_ClearCloudClear: %.4f, loss_identity_Cloud: %.4f, loss_identity_Clear: %.4f, loss_pix_Cloud: %.4f, loss_pix_Clear: %.4f' % (loss_GAN_Cloud2Clear.data, 
            loss_GAN_Clear2Cloud.data, loss_cycle_CloudClearCloud.data, loss_cycle_ClearCloudClear.data, loss_identity_Cloud.data, loss_identity_Clear.data, loss_pix_Cloud.data, loss_pix_Clear.data)) 

        save_path='%s/%s' % (save_name, 'training')
        if not os.path.exists(save_path):
            os.makedirs(save_path)

        save_image(torch.cat([
            real_Cloud.data.cpu()[0] * 0.5 + 0.5,
            mask_Clear.data.cpu()[0],
            fake_Clear.data.cpu()[0]*0.5+0.5, temp_Clear.data.cpu()[0]*0.5+0.5], 2),
            '%s/%04d_%04d_progress_B.png' % (save_path,epoch+1,i+1))

        save_image(torch.cat([
            real_Clear.data.cpu()[0] * 0.5 + 0.5,
            mask_Cloud.data.cpu()[0],
            fake_Cloud.data.cpu()[0]*0.5+0.5, temp_Clear.data.cpu()[0]*0.5+0.5], 2),
            '%s/%04d_%04d_progress_A.png' % (save_path,epoch+1,i+1))

    # Update learning rates
    lr_scheduler_G.step()
    lr_scheduler_D.step()

    torch.save(netG_Cloud2Clear.state_dict(), '%s/%s' % (save_name, 'netG_Cloud2Clear.pth'))
    torch.save(netG_Clear2Cloud.state_dict(), '%s/%s' % (save_name, 'netG_Clear2Cloud.pth'))
    torch.save(netD_Cloud.state_dict(), '%s/%s' % (save_name, 'netD_Cloud.pth'))
    torch.save(netD_Clear.state_dict(), '%s/%s' % (save_name, 'netD_Clear.pth'))
# Out:
# ---------- Networks initialized -------------
# Generator(
#   (model): Sequential(
#     (0): ReflectionPad2d((3, 3, 3, 3))
#     (1): Conv2d(3, 64, kernel_size=(7, 7), stride=(1, 1))
#     (2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): ReLU(inplace=True)
#     (4): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (5): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (8): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (9): ReLU(inplace=True)
#     (10): ResnetBlock(
#       (conv_block): Sequential(
#         (0): ReflectionPad2d((1, 1, 1, 1))
#         (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1))
#         (2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (3): ReLU(inplace=True)
#         (4): ReflectionPad2d((1, 1, 1, 1))
#         (5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1))
#         (6): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (11): ResnetBlock(
#       (conv_block): Sequential(
#         (0): ReflectionPad2d((1, 1, 1, 1))
#         (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1))
#         (2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (3): ReLU(inplace=True)
#         (4): ReflectionPad2d((1, 1, 1, 1))
#         (5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1))
#         (6): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (12): ResnetBlock(
#       (conv_block): Sequential(
#         (0): ReflectionPad2d((1, 1, 1, 1))
#         (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1))
#         (2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (3): ReLU(inplace=True)
#         (4): ReflectionPad2d((1, 1, 1, 1))
#         (5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1))
#         (6): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (13): ResnetBlock(
#       (conv_block): Sequential(
#         (0): ReflectionPad2d((1, 1, 1, 1))
#         (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1))
#         (2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (3): ReLU(inplace=True)
#         (4): ReflectionPad2d((1, 1, 1, 1))
#         (5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1))
#         (6): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (14): ResnetBlock(
#       (conv_block): Sequential(
#         (0): ReflectionPad2d((1, 1, 1, 1))
#         (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1))
#         (2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (3): ReLU(inplace=True)
#         (4): ReflectionPad2d((1, 1, 1, 1))
#         (5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1))
#         (6): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (15): ResnetBlock(
#       (conv_block): Sequential(
#         (0): ReflectionPad2d((1, 1, 1, 1))
#         (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1))
#         (2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (3): ReLU(inplace=True)
#         (4): ReflectionPad2d((1, 1, 1, 1))
#         (5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1))
#         (6): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (16): ReflectionPad2d((1, 1, 1, 1))
#     (17): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1))
#     (18): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (19): ReLU(inplace=True)
#     (20): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1))
#     (21): PixelShuffle(upscale_factor=2)
#     (22): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (23): ReLU(inplace=True)
#     (24): ReflectionPad2d((1, 1, 1, 1))
#     (25): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1))
#     (26): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (27): ReLU(inplace=True)
#     (28): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1))
#     (29): PixelShuffle(upscale_factor=2)
#     (30): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (31): ReLU(inplace=True)
#     (32): ReflectionPad2d((3, 3, 3, 3))
#     (33): Conv2d(64, 4, kernel_size=(7, 7), stride=(1, 1))
#   )
# )
# Total number of parameters: 7931332
# Generator(
#   (model): Sequential(
#     (0): ReflectionPad2d((3, 3, 3, 3))
#     (1): Conv2d(3, 64, kernel_size=(7, 7), stride=(1, 1))
#     (2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): ReLU(inplace=True)
#     (4): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (5): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (8): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (9): ReLU(inplace=True)
#     (10): ResnetBlock(
#       (conv_block): Sequential(
#         (0): ReflectionPad2d((1, 1, 1, 1))
#         (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1))
#         (2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (3): ReLU(inplace=True)
#         (4): ReflectionPad2d((1, 1, 1, 1))
#         (5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1))
#         (6): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (11): ResnetBlock(
#       (conv_block): Sequential(
#         (0): ReflectionPad2d((1, 1, 1, 1))
#         (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1))
#         (2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (3): ReLU(inplace=True)
#         (4): ReflectionPad2d((1, 1, 1, 1))
#         (5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1))
#         (6): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (12): ResnetBlock(
#       (conv_block): Sequential(
#         (0): ReflectionPad2d((1, 1, 1, 1))
#         (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1))
#         (2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (3): ReLU(inplace=True)
#         (4): ReflectionPad2d((1, 1, 1, 1))
#         (5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1))
#         (6): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (13): ResnetBlock(
#       (conv_block): Sequential(
#         (0): ReflectionPad2d((1, 1, 1, 1))
#         (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1))
#         (2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (3): ReLU(inplace=True)
#         (4): ReflectionPad2d((1, 1, 1, 1))
#         (5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1))
#         (6): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (14): ResnetBlock(
#       (conv_block): Sequential(
#         (0): ReflectionPad2d((1, 1, 1, 1))
#         (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1))
#         (2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (3): ReLU(inplace=True)
#         (4): ReflectionPad2d((1, 1, 1, 1))
#         (5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1))
#         (6): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (15): ResnetBlock(
#       (conv_block): Sequential(
#         (0): ReflectionPad2d((1, 1, 1, 1))
#         (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1))
#         (2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (3): ReLU(inplace=True)
#         (4): ReflectionPad2d((1, 1, 1, 1))
#         (5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1))
#         (6): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (16): ReflectionPad2d((1, 1, 1, 1))
#     (17): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1))
#     (18): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (19): ReLU(inplace=True)
#     (20): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1))
#     (21): PixelShuffle(upscale_factor=2)
#     (22): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (23): ReLU(inplace=True)
#     (24): ReflectionPad2d((1, 1, 1, 1))
#     (25): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1))
#     (26): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (27): ReLU(inplace=True)
#     (28): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1))
#     (29): PixelShuffle(upscale_factor=2)
#     (30): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (31): ReLU(inplace=True)
#     (32): ReflectionPad2d((3, 3, 3, 3))
#     (33): Conv2d(64, 4, kernel_size=(7, 7), stride=(1, 1))
#   )
# )
# Total number of parameters: 7931332
# Discriminator(
#   (conv_tower): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(4, 4), stride=(2, 2))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): LeakyReLU(negative_slope=0.01)
#     (3): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2))
#     (4): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): LeakyReLU(negative_slope=0.01)
#     (6): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2))
#     (7): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (8): LeakyReLU(negative_slope=0.01)
#     (9): Conv2d(256, 512, kernel_size=(4, 4), stride=(2, 2))
#     (10): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (11): LeakyReLU(negative_slope=0.01)
#     (12): Conv2d(512, 512, kernel_size=(4, 4), stride=(1, 1))
#     (13): LeakyReLU(negative_slope=0.01)
#     (14): AdaptiveAvgPool2d(output_size=(1, 1))
#     (15): Conv2d(512, 1, kernel_size=(1, 1), stride=(1, 1))
#   )
# )
# Total number of parameters: 6953793
# Discriminator(
#   (conv_tower): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(4, 4), stride=(2, 2))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): LeakyReLU(negative_slope=0.01)
#     (3): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2))
#     (4): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): LeakyReLU(negative_slope=0.01)
#     (6): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2))
#     (7): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (8): LeakyReLU(negative_slope=0.01)
#     (9): Conv2d(256, 512, kernel_size=(4, 4), stride=(2, 2))
#     (10): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (11): LeakyReLU(negative_slope=0.01)
#     (12): Conv2d(512, 512, kernel_size=(4, 4), stride=(1, 1))
#     (13): LeakyReLU(negative_slope=0.01)
#     (14): AdaptiveAvgPool2d(output_size=(1, 1))
#     (15): Conv2d(512, 1, kernel_size=(1, 1), stride=(1, 1))
#   )
# )
# Total number of parameters: 6953793
# -----------------------------------------------
# <ipython-input-1-31317655205d>:123: UserWarning: nn.init.normal is now deprecated in favor of nn.init.normal_.
#   torch.nn.init.normal(m.weight.data, 0.0, 0.02)
# <ipython-input-1-31317655205d>:125: UserWarning: nn.init.normal is now deprecated in favor of nn.init.normal_.
#   torch.nn.init.normal(m.weight.data, 1.0, 0.02)
# using curriculum gan
# Epoch [1/60], Batch [1/450], loss_D: 0.9869, loss_G: 2.3385
# loss_GAN_Cloud2Clear: 1.1135, loss_GAN_Clear2Cloud: 2.4037, loss_cycle_CloudClearCloud: 0.5184, loss_cycle_ClearCloudClear: 0.4538, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.4150, loss_pix_Clear: 0.3081
# using curriculum gan
# Epoch [1/60], Batch [2/450], loss_D: 0.5325, loss_G: 0.5415
# loss_GAN_Cloud2Clear: 0.0519, loss_GAN_Clear2Cloud: 0.0489, loss_cycle_CloudClearCloud: 0.4326, loss_cycle_ClearCloudClear: 0.6214, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.3852, loss_pix_Clear: 0.4037
# using curriculum gan
# Epoch [1/60], Batch [3/450], loss_D: 0.4788, loss_G: 0.5044
# loss_GAN_Cloud2Clear: 0.0755, loss_GAN_Clear2Cloud: 0.0196, loss_cycle_CloudClearCloud: 0.3635, loss_cycle_ClearCloudClear: 0.5620, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.3639, loss_pix_Clear: 0.3739
# using curriculum gan
# Epoch [1/60], Batch [4/450], loss_D: 0.2796, loss_G: 0.8633
# loss_GAN_Cloud2Clear: 0.7446, loss_GAN_Clear2Cloud: 0.1365, loss_cycle_CloudClearCloud: 0.3918, loss_cycle_ClearCloudClear: 0.6305, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.3558, loss_pix_Clear: 0.2123
# using curriculum gan
# Epoch [1/60], Batch [5/450], loss_D: 0.2827, loss_G: 0.8972
# loss_GAN_Cloud2Clear: 0.4415, loss_GAN_Clear2Cloud: 0.6175, loss_cycle_CloudClearCloud: 0.3988, loss_cycle_ClearCloudClear: 0.3989, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.5060, loss_pix_Clear: 0.2077
# using curriculum gan
# Epoch [1/60], Batch [6/450], loss_D: 0.2602, loss_G: 0.6834
# loss_GAN_Cloud2Clear: 0.1293, loss_GAN_Clear2Cloud: 0.5077, loss_cycle_CloudClearCloud: 0.3873, loss_cycle_ClearCloudClear: 0.3999, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.4982, loss_pix_Clear: 0.2004
# using curriculum gan
# Epoch [1/60], Batch [7/450], loss_D: 0.2221, loss_G: 0.5658
# loss_GAN_Cloud2Clear: 0.2212, loss_GAN_Clear2Cloud: 0.2182, loss_cycle_CloudClearCloud: 0.3129, loss_cycle_ClearCloudClear: 0.6324, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.3959, loss_pix_Clear: 0.1695
# using curriculum gan
# Epoch [1/60], Batch [8/450], loss_D: 0.2245, loss_G: 0.5609
# loss_GAN_Cloud2Clear: 0.3698, loss_GAN_Clear2Cloud: 0.1433, loss_cycle_CloudClearCloud: 0.3485, loss_cycle_ClearCloudClear: 0.4214, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.3767, loss_pix_Clear: 0.1822
# using curriculum gan
# Epoch [1/60], Batch [9/450], loss_D: 0.2275, loss_G: 0.5739
# loss_GAN_Cloud2Clear: 0.2829, loss_GAN_Clear2Cloud: 0.2955, loss_cycle_CloudClearCloud: 0.3679, loss_cycle_ClearCloudClear: 0.4981, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.4062, loss_pix_Clear: 0.2390
# using curriculum gan
# Epoch [1/60], Batch [10/450], loss_D: 0.2345, loss_G: 0.5084
# loss_GAN_Cloud2Clear: 0.2784, loss_GAN_Clear2Cloud: 0.2057, loss_cycle_CloudClearCloud: 0.3458, loss_cycle_ClearCloudClear: 0.4820, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.4355, loss_pix_Clear: 0.2239
# using curriculum gan
# Epoch [1/60], Batch [11/450], loss_D: 0.1911, loss_G: 0.6877
# loss_GAN_Cloud2Clear: 0.4243, loss_GAN_Clear2Cloud: 0.4904, loss_cycle_CloudClearCloud: 0.3541, loss_cycle_ClearCloudClear: 0.4279, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.3901, loss_pix_Clear: 0.1700
# using curriculum gan
# Epoch [1/60], Batch [12/450], loss_D: 0.1787, loss_G: 0.5172
# loss_GAN_Cloud2Clear: 0.2825, loss_GAN_Clear2Cloud: 0.2987, loss_cycle_CloudClearCloud: 0.4020, loss_cycle_ClearCloudClear: 0.4119, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.4135, loss_pix_Clear: 0.1624
# using curriculum gan
# Epoch [1/60], Batch [13/450], loss_D: 0.1916, loss_G: 0.5556
# loss_GAN_Cloud2Clear: 0.5126, loss_GAN_Clear2Cloud: 0.0980, loss_cycle_CloudClearCloud: 0.3795, loss_cycle_ClearCloudClear: 0.4254, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.4015, loss_pix_Clear: 0.1620
# using curriculum gan
# Epoch [1/60], Batch [14/450], loss_D: 0.1109, loss_G: 0.7085
# loss_GAN_Cloud2Clear: 0.4947, loss_GAN_Clear2Cloud: 0.4143, loss_cycle_CloudClearCloud: 0.3194, loss_cycle_ClearCloudClear: 0.5009, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.3731, loss_pix_Clear: 0.1214
# using curriculum gan
# Epoch [1/60], Batch [15/450], loss_D: 0.2131, loss_G: 0.8233
# loss_GAN_Cloud2Clear: 0.3226, loss_GAN_Clear2Cloud: 0.8611, loss_cycle_CloudClearCloud: 0.4970, loss_cycle_ClearCloudClear: 0.4521, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.6133, loss_pix_Clear: 0.2002
# using curriculum gan
# Epoch [1/60], Batch [16/450], loss_D: 0.3349, loss_G: 0.8552
# loss_GAN_Cloud2Clear: 1.0902, loss_GAN_Clear2Cloud: 0.1840, loss_cycle_CloudClearCloud: 0.3263, loss_cycle_ClearCloudClear: 0.4036, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.4250, loss_pix_Clear: 0.1299
# using curriculum gan
# Epoch [1/60], Batch [17/450], loss_D: 0.3626, loss_G: 0.2511
# loss_GAN_Cloud2Clear: 0.0373, loss_GAN_Clear2Cloud: 0.0699, loss_cycle_CloudClearCloud: 0.3249, loss_cycle_ClearCloudClear: 0.4134, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.4120, loss_pix_Clear: 0.1611
# using curriculum gan
# Epoch [1/60], Batch [18/450], loss_D: 0.1809, loss_G: 0.7050
# loss_GAN_Cloud2Clear: 0.5884, loss_GAN_Clear2Cloud: 0.3135, loss_cycle_CloudClearCloud: 0.4721, loss_cycle_ClearCloudClear: 0.8618, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.4568, loss_pix_Clear: 0.1032
# using curriculum gan
# Epoch [1/60], Batch [19/450], loss_D: 0.1692, loss_G: 0.8619
# loss_GAN_Cloud2Clear: 0.8110, loss_GAN_Clear2Cloud: 0.4444, loss_cycle_CloudClearCloud: 0.3694, loss_cycle_ClearCloudClear: 0.9088, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.4640, loss_pix_Clear: 0.1086
# using curriculum gan
# Epoch [1/60], Batch [20/450], loss_D: 0.2107, loss_G: 0.4271
# loss_GAN_Cloud2Clear: 0.2093, loss_GAN_Clear2Cloud: 0.2589, loss_cycle_CloudClearCloud: 0.3617, loss_cycle_ClearCloudClear: 0.5536, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.4339, loss_pix_Clear: 0.0928
# using curriculum gan
# Epoch [1/60], Batch [21/450], loss_D: 0.2121, loss_G: 0.5695
# loss_GAN_Cloud2Clear: 0.5818, loss_GAN_Clear2Cloud: 0.1546, loss_cycle_CloudClearCloud: 0.5100, loss_cycle_ClearCloudClear: 0.4673, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.6225, loss_pix_Clear: 0.1589
# using curriculum gan
# Epoch [1/60], Batch [22/450], loss_D: 0.1854, loss_G: 0.4109
# loss_GAN_Cloud2Clear: 0.2389, loss_GAN_Clear2Cloud: 0.1571, loss_cycle_CloudClearCloud: 0.4637, loss_cycle_ClearCloudClear: 0.7699, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.4902, loss_pix_Clear: 0.0923
# using curriculum gan
# Epoch [1/60], Batch [23/450], loss_D: 0.3616, loss_G: 1.2267
# loss_GAN_Cloud2Clear: 0.5374, loss_GAN_Clear2Cloud: 1.5834, loss_cycle_CloudClearCloud: 0.4443, loss_cycle_ClearCloudClear: 0.5336, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.5022, loss_pix_Clear: 0.1039
# using curriculum gan
# Epoch [1/60], Batch [24/450], loss_D: 0.3185, loss_G: 0.4496
# loss_GAN_Cloud2Clear: 0.5267, loss_GAN_Clear2Cloud: 0.0064, loss_cycle_CloudClearCloud: 0.4059, loss_cycle_ClearCloudClear: 0.5562, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.4729, loss_pix_Clear: 0.1268
# using curriculum gan
# Epoch [1/60], Batch [25/450], loss_D: 0.1527, loss_G: 0.6566
# loss_GAN_Cloud2Clear: 0.6380, loss_GAN_Clear2Cloud: 0.2747, loss_cycle_CloudClearCloud: 0.5345, loss_cycle_ClearCloudClear: 0.5660, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.6221, loss_pix_Clear: 0.0845
# using curriculum gan
# Epoch [1/60], Batch [26/450], loss_D: 0.2964, loss_G: 0.6005
# loss_GAN_Cloud2Clear: 0.2292, loss_GAN_Clear2Cloud: 0.6023, loss_cycle_CloudClearCloud: 0.4944, loss_cycle_ClearCloudClear: 0.5801, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.5735, loss_pix_Clear: 0.1388
# using curriculum gan
# Epoch [1/60], Batch [27/450], loss_D: 0.2079, loss_G: 0.3605
# loss_GAN_Cloud2Clear: 0.1617, loss_GAN_Clear2Cloud: 0.1747, loss_cycle_CloudClearCloud: 0.4914, loss_cycle_ClearCloudClear: 0.5898, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.5418, loss_pix_Clear: 0.0803
# using curriculum gan
# Epoch [1/60], Batch [28/450], loss_D: 0.2696, loss_G: 0.8466
# loss_GAN_Cloud2Clear: 1.0723, loss_GAN_Clear2Cloud: 0.2495, loss_cycle_CloudClearCloud: 0.5088, loss_cycle_ClearCloudClear: 0.6042, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.5744, loss_pix_Clear: 0.1081
# using curriculum gan
# Epoch [1/60], Batch [29/450], loss_D: 0.3198, loss_G: 0.3990
# loss_GAN_Cloud2Clear: 0.0166, loss_GAN_Clear2Cloud: 0.3865, loss_cycle_CloudClearCloud: 0.5064, loss_cycle_ClearCloudClear: 0.7559, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.5655, loss_pix_Clear: 0.0643
# using curriculum gan
# Epoch [1/60], Batch [30/450], loss_D: 0.1540, loss_G: 0.8968
# loss_GAN_Cloud2Clear: 1.1718, loss_GAN_Clear2Cloud: 0.2598, loss_cycle_CloudClearCloud: 0.5367, loss_cycle_ClearCloudClear: 0.5961, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.5889, loss_pix_Clear: 0.1168
# using curriculum gan
# Epoch [1/60], Batch [31/450], loss_D: 0.2451, loss_G: 0.5669
# loss_GAN_Cloud2Clear: 0.3074, loss_GAN_Clear2Cloud: 0.4733, loss_cycle_CloudClearCloud: 0.5304, loss_cycle_ClearCloudClear: 0.5280, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.5783, loss_pix_Clear: 0.0627
# using curriculum gan
# Epoch [1/60], Batch [32/450], loss_D: 0.2207, loss_G: 0.3499
# loss_GAN_Cloud2Clear: 0.1534, loss_GAN_Clear2Cloud: 0.1978, loss_cycle_CloudClearCloud: 0.4741, loss_cycle_ClearCloudClear: 0.6500, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.5527, loss_pix_Clear: 0.1461
# using curriculum gan
# Epoch [1/60], Batch [33/450], loss_D: 0.2219, loss_G: 0.3803
# loss_GAN_Cloud2Clear: 0.3008, loss_GAN_Clear2Cloud: 0.1256, loss_cycle_CloudClearCloud: 0.5131, loss_cycle_ClearCloudClear: 0.5443, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.5650, loss_pix_Clear: 0.0769
# using curriculum gan
# Epoch [1/60], Batch [34/450], loss_D: 0.4248, loss_G: 1.0170
# loss_GAN_Cloud2Clear: 0.7774, loss_GAN_Clear2Cloud: 0.9470, loss_cycle_CloudClearCloud: 0.4390, loss_cycle_ClearCloudClear: 0.5615, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.5025, loss_pix_Clear: 0.0974
# using curriculum gan
# Epoch [1/60], Batch [35/450], loss_D: 0.2959, loss_G: 0.3434
# loss_GAN_Cloud2Clear: 0.0117, loss_GAN_Clear2Cloud: 0.3314, loss_cycle_CloudClearCloud: 0.5525, loss_cycle_ClearCloudClear: 0.5603, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.6260, loss_pix_Clear: 0.0918
# using curriculum gan
# Epoch [1/60], Batch [36/450], loss_D: 0.2474, loss_G: 0.5517
# loss_GAN_Cloud2Clear: 0.7325, loss_GAN_Clear2Cloud: 0.0377, loss_cycle_CloudClearCloud: 0.5182, loss_cycle_ClearCloudClear: 0.5885, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.5869, loss_pix_Clear: 0.0605
# using curriculum gan
# Epoch [1/60], Batch [37/450], loss_D: 0.1657, loss_G: 0.5756
# loss_GAN_Cloud2Clear: 0.3942, loss_GAN_Clear2Cloud: 0.4151, loss_cycle_CloudClearCloud: 0.5345, loss_cycle_ClearCloudClear: 0.6139, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.5828, loss_pix_Clear: 0.0472
# using curriculum gan
# Epoch [1/60], Batch [38/450], loss_D: 0.2312, loss_G: 0.6255
# loss_GAN_Cloud2Clear: 0.4289, loss_GAN_Clear2Cloud: 0.4772, loss_cycle_CloudClearCloud: 0.4620, loss_cycle_ClearCloudClear: 0.7458, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.5159, loss_pix_Clear: 0.0491
# using curriculum gan
# Epoch [1/60], Batch [39/450], loss_D: 0.2776, loss_G: 0.3680
# loss_GAN_Cloud2Clear: 0.1494, loss_GAN_Clear2Cloud: 0.2391, loss_cycle_CloudClearCloud: 0.5919, loss_cycle_ClearCloudClear: 0.6140, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.6470, loss_pix_Clear: 0.0824
# using curriculum gan
# Epoch [1/60], Batch [40/450], loss_D: 0.2962, loss_G: 0.4496
# loss_GAN_Cloud2Clear: 0.5160, loss_GAN_Clear2Cloud: 0.0494, loss_cycle_CloudClearCloud: 0.5279, loss_cycle_ClearCloudClear: 0.6515, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.5818, loss_pix_Clear: 0.0560
# using curriculum gan
# Epoch [1/60], Batch [41/450], loss_D: 0.2240, loss_G: 0.4715
# loss_GAN_Cloud2Clear: 0.1579, loss_GAN_Clear2Cloud: 0.4300, loss_cycle_CloudClearCloud: 0.6099, loss_cycle_ClearCloudClear: 0.6712, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.6630, loss_pix_Clear: 0.0525
# using curriculum gan
# Epoch [1/60], Batch [42/450], loss_D: 0.2557, loss_G: 0.4133
# loss_GAN_Cloud2Clear: 0.1368, loss_GAN_Clear2Cloud: 0.3278, loss_cycle_CloudClearCloud: 0.6068, loss_cycle_ClearCloudClear: 0.6964, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.6602, loss_pix_Clear: 0.0499
# using curriculum gan
# Epoch [1/60], Batch [43/450], loss_D: 0.3823, loss_G: 0.8573
# loss_GAN_Cloud2Clear: 0.9068, loss_GAN_Clear2Cloud: 0.4704, loss_cycle_CloudClearCloud: 0.6090, loss_cycle_ClearCloudClear: 0.6779, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.6625, loss_pix_Clear: 0.0603
# using curriculum gan
# Epoch [1/60], Batch [44/450], loss_D: 0.4129, loss_G: 0.2276
# loss_GAN_Cloud2Clear: 0.0006, loss_GAN_Clear2Cloud: 0.0822, loss_cycle_CloudClearCloud: 0.6113, loss_cycle_ClearCloudClear: 0.7807, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.6655, loss_pix_Clear: 0.0674
# using curriculum gan
# Epoch [1/60], Batch [45/450], loss_D: 0.2427, loss_G: 0.7458
# loss_GAN_Cloud2Clear: 0.8515, loss_GAN_Clear2Cloud: 0.2899, loss_cycle_CloudClearCloud: 0.5860, loss_cycle_ClearCloudClear: 0.7681, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.6425, loss_pix_Clear: 0.0363
# using curriculum gan
# Epoch [1/60], Batch [46/450], loss_D: 0.2123, loss_G: 0.6067
# loss_GAN_Cloud2Clear: 0.5047, loss_GAN_Clear2Cloud: 0.3497, loss_cycle_CloudClearCloud: 0.6609, loss_cycle_ClearCloudClear: 0.7101, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.7023, loss_pix_Clear: 0.0329
# using curriculum gan
# Epoch [1/60], Batch [47/450], loss_D: 0.3181, loss_G: 0.3091
# loss_GAN_Cloud2Clear: 0.0268, loss_GAN_Clear2Cloud: 0.2564, loss_cycle_CloudClearCloud: 0.6074, loss_cycle_ClearCloudClear: 0.6256, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.6481, loss_pix_Clear: 0.0301
# using curriculum gan
# Epoch [1/60], Batch [48/450], loss_D: 0.2194, loss_G: 0.5517
# loss_GAN_Cloud2Clear: 0.6082, loss_GAN_Clear2Cloud: 0.1525, loss_cycle_CloudClearCloud: 0.5903, loss_cycle_ClearCloudClear: 0.7495, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.6296, loss_pix_Clear: 0.0685
# using curriculum gan
# Epoch [1/60], Batch [49/450], loss_D: 0.1906, loss_G: 0.5320
# loss_GAN_Cloud2Clear: 0.3810, loss_GAN_Clear2Cloud: 0.3590, loss_cycle_CloudClearCloud: 0.5737, loss_cycle_ClearCloudClear: 0.6826, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.6095, loss_pix_Clear: 0.0464
# using curriculum gan
# Epoch [1/60], Batch [50/450], loss_D: 0.1515, loss_G: 0.4429
# loss_GAN_Cloud2Clear: 0.3279, loss_GAN_Clear2Cloud: 0.2527, loss_cycle_CloudClearCloud: 0.4577, loss_cycle_ClearCloudClear: 0.7000, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.5035, loss_pix_Clear: 0.0608
# using curriculum gan
# Epoch [1/60], Batch [51/450], loss_D: 0.1484, loss_G: 0.5722
# loss_GAN_Cloud2Clear: 0.3295, loss_GAN_Clear2Cloud: 0.4960, loss_cycle_CloudClearCloud: 0.6050, loss_cycle_ClearCloudClear: 0.6452, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.6438, loss_pix_Clear: 0.0265
# using curriculum gan
# Epoch [1/60], Batch [52/450], loss_D: 0.1292, loss_G: 0.4158
# loss_GAN_Cloud2Clear: 0.4105, loss_GAN_Clear2Cloud: 0.1097, loss_cycle_CloudClearCloud: 0.5371, loss_cycle_ClearCloudClear: 0.6872, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.5748, loss_pix_Clear: 0.0306
# using curriculum gan
# Epoch [1/60], Batch [53/450], loss_D: 0.2406, loss_G: 0.3263
# loss_GAN_Cloud2Clear: 0.1536, loss_GAN_Clear2Cloud: 0.1905, loss_cycle_CloudClearCloud: 0.5695, loss_cycle_ClearCloudClear: 0.6180, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.5972, loss_pix_Clear: 0.0286
# using curriculum gan
# Epoch [1/60], Batch [54/450], loss_D: 0.2046, loss_G: 0.5384
# loss_GAN_Cloud2Clear: 0.4653, loss_GAN_Clear2Cloud: 0.3113, loss_cycle_CloudClearCloud: 0.5146, loss_cycle_ClearCloudClear: 0.6567, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.5529, loss_pix_Clear: 0.0324
# using curriculum gan
# Epoch [1/60], Batch [55/450], loss_D: 0.2467, loss_G: 0.4466
# loss_GAN_Cloud2Clear: 0.4407, loss_GAN_Clear2Cloud: 0.1383, loss_cycle_CloudClearCloud: 0.5380, loss_cycle_ClearCloudClear: 0.7003, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.5758, loss_pix_Clear: 0.0562
# using curriculum gan
# Epoch [1/60], Batch [56/450], loss_D: 0.1257, loss_G: 0.2778
# loss_GAN_Cloud2Clear: 0.0566, loss_GAN_Clear2Cloud: 0.2193, loss_cycle_CloudClearCloud: 0.5675, loss_cycle_ClearCloudClear: 0.5344, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.6006, loss_pix_Clear: 0.0188
# using curriculum gan
# Epoch [1/60], Batch [57/450], loss_D: 0.1917, loss_G: 0.3365
# loss_GAN_Cloud2Clear: 0.0437, loss_GAN_Clear2Cloud: 0.3238, loss_cycle_CloudClearCloud: 0.5336, loss_cycle_ClearCloudClear: 0.6572, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.5737, loss_pix_Clear: 0.0697
# using curriculum gan
# Epoch [1/60], Batch [58/450], loss_D: 0.1940, loss_G: 0.5747
# loss_GAN_Cloud2Clear: 0.5624, loss_GAN_Clear2Cloud: 0.3388, loss_cycle_CloudClearCloud: 0.4880, loss_cycle_ClearCloudClear: 0.5085, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.5331, loss_pix_Clear: 0.0228
# using curriculum gan
# Epoch [1/60], Batch [59/450], loss_D: 0.2284, loss_G: 0.3480
# loss_GAN_Cloud2Clear: 0.2851, loss_GAN_Clear2Cloud: 0.0810, loss_cycle_CloudClearCloud: 0.5577, loss_cycle_ClearCloudClear: 0.7563, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.5940, loss_pix_Clear: 0.0463
# using curriculum gan
# Epoch [1/60], Batch [60/450], loss_D: 0.2454, loss_G: 0.4785
# loss_GAN_Cloud2Clear: 0.2706, loss_GAN_Clear2Cloud: 0.3628, loss_cycle_CloudClearCloud: 0.5969, loss_cycle_ClearCloudClear: 0.7238, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.6372, loss_pix_Clear: 0.0498
# using curriculum gan
# Epoch [1/60], Batch [61/450], loss_D: 0.2414, loss_G: 0.6707
# loss_GAN_Cloud2Clear: 0.6177, loss_GAN_Clear2Cloud: 0.3727, loss_cycle_CloudClearCloud: 0.6403, loss_cycle_ClearCloudClear: 0.8125, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.6827, loss_pix_Clear: 0.0494
# using curriculum gan
# Epoch [1/60], Batch [62/450], loss_D: 0.2235, loss_G: 0.2350
# loss_GAN_Cloud2Clear: 0.0514, loss_GAN_Clear2Cloud: 0.0675, loss_cycle_CloudClearCloud: 0.6974, loss_cycle_ClearCloudClear: 0.7058, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.7430, loss_pix_Clear: 0.0508
# using curriculum gan
# Epoch [1/60], Batch [63/450], loss_D: 0.8334, loss_G: 0.6572
# loss_GAN_Cloud2Clear: 0.4304, loss_GAN_Clear2Cloud: 0.5543, loss_cycle_CloudClearCloud: 0.6410, loss_cycle_ClearCloudClear: 0.7147, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.6887, loss_pix_Clear: 0.0572
# using curriculum gan
# Epoch [1/60], Batch [64/450], loss_D: 0.4777, loss_G: 1.5205
# loss_GAN_Cloud2Clear: 2.0531, loss_GAN_Clear2Cloud: 0.7002, loss_cycle_CloudClearCloud: 0.5571, loss_cycle_ClearCloudClear: 0.7026, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.6128, loss_pix_Clear: 0.0497
# using curriculum gan
# Epoch [1/60], Batch [65/450], loss_D: 0.3397, loss_G: 0.6020
# loss_GAN_Cloud2Clear: 0.8473, loss_GAN_Clear2Cloud: 0.0481, loss_cycle_CloudClearCloud: 0.6031, loss_cycle_ClearCloudClear: 0.6437, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.6479, loss_pix_Clear: 0.0463
# using curriculum gan
# Epoch [1/60], Batch [66/450], loss_D: 0.3827, loss_G: 0.6627
# loss_GAN_Cloud2Clear: 0.1267, loss_GAN_Clear2Cloud: 0.9188, loss_cycle_CloudClearCloud: 0.4876, loss_cycle_ClearCloudClear: 0.6386, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.5241, loss_pix_Clear: 0.0496
# using curriculum gan
# Epoch [1/60], Batch [67/450], loss_D: 0.1524, loss_G: 0.2617
# loss_GAN_Cloud2Clear: 0.0403, loss_GAN_Clear2Cloud: 0.2240, loss_cycle_CloudClearCloud: 0.4940, loss_cycle_ClearCloudClear: 0.5167, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.5192, loss_pix_Clear: 0.0487
# using curriculum gan
# Epoch [1/60], Batch [68/450], loss_D: 0.2041, loss_G: 0.2474
# loss_GAN_Cloud2Clear: 0.1827, loss_GAN_Clear2Cloud: 0.0296, loss_cycle_CloudClearCloud: 0.4697, loss_cycle_ClearCloudClear: 0.6390, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.5110, loss_pix_Clear: 0.0470
# using curriculum gan
# Epoch [1/60], Batch [69/450], loss_D: 0.1294, loss_G: 0.5491
# loss_GAN_Cloud2Clear: 0.6463, loss_GAN_Clear2Cloud: 0.2024, loss_cycle_CloudClearCloud: 0.4585, loss_cycle_ClearCloudClear: 0.5304, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.5000, loss_pix_Clear: 0.0472
# using curriculum gan
# Epoch [1/60], Batch [70/450], loss_D: 0.3075, loss_G: 0.9419
# loss_GAN_Cloud2Clear: 0.4309, loss_GAN_Clear2Cloud: 1.2232, loss_cycle_CloudClearCloud: 0.4499, loss_cycle_ClearCloudClear: 0.4744, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.4827, loss_pix_Clear: 0.0491
# using curriculum gan
# Epoch [1/60], Batch [71/450], loss_D: 0.1793, loss_G: 0.3169
# loss_GAN_Cloud2Clear: 0.1726, loss_GAN_Clear2Cloud: 0.2052, loss_cycle_CloudClearCloud: 0.4802, loss_cycle_ClearCloudClear: 0.5226, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.5300, loss_pix_Clear: 0.0527
# using curriculum gan
# Epoch [1/60], Batch [72/450], loss_D: 0.2138, loss_G: 0.3278
# loss_GAN_Cloud2Clear: 0.2524, loss_GAN_Clear2Cloud: 0.1159, loss_cycle_CloudClearCloud: 0.6197, loss_cycle_ClearCloudClear: 0.5314, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.6484, loss_pix_Clear: 0.0500
# using curriculum gan
# Epoch [1/60], Batch [73/450], loss_D: 0.1706, loss_G: 0.5197
# loss_GAN_Cloud2Clear: 0.5901, loss_GAN_Clear2Cloud: 0.1908, loss_cycle_CloudClearCloud: 0.4767, loss_cycle_ClearCloudClear: 0.5917, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.5163, loss_pix_Clear: 0.0504
# using curriculum gan
# Epoch [1/60], Batch [74/450], loss_D: 0.2330, loss_G: 0.4195
# loss_GAN_Cloud2Clear: 0.2764, loss_GAN_Clear2Cloud: 0.3025, loss_cycle_CloudClearCloud: 0.5981, loss_cycle_ClearCloudClear: 0.4446, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.6256, loss_pix_Clear: 0.0502
# using curriculum gan
# Epoch [1/60], Batch [75/450], loss_D: 0.2006, loss_G: 0.3158
# loss_GAN_Cloud2Clear: 0.1880, loss_GAN_Clear2Cloud: 0.2103, loss_cycle_CloudClearCloud: 0.4572, loss_cycle_ClearCloudClear: 0.4703, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.4949, loss_pix_Clear: 0.0527
# using curriculum gan
# Epoch [1/60], Batch [76/450], loss_D: 0.2532, loss_G: 0.4849
# loss_GAN_Cloud2Clear: 0.5942, loss_GAN_Clear2Cloud: 0.1082, loss_cycle_CloudClearCloud: 0.4527, loss_cycle_ClearCloudClear: 0.6548, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.4852, loss_pix_Clear: 0.0636
# using curriculum gan
# Epoch [1/60], Batch [77/450], loss_D: 0.1822, loss_G: 0.3978
# loss_GAN_Cloud2Clear: 0.1605, loss_GAN_Clear2Cloud: 0.3990, loss_cycle_CloudClearCloud: 0.4515, loss_cycle_ClearCloudClear: 0.4847, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.4877, loss_pix_Clear: 0.0489
# using curriculum gan
# Epoch [1/60], Batch [78/450], loss_D: 0.2266, loss_G: 0.2497
# loss_GAN_Cloud2Clear: 0.0972, loss_GAN_Clear2Cloud: 0.1353, loss_cycle_CloudClearCloud: 0.4931, loss_cycle_ClearCloudClear: 0.6073, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.5207, loss_pix_Clear: 0.0579
# using curriculum gan
# Epoch [1/60], Batch [79/450], loss_D: 0.2546, loss_G: 0.4377
# loss_GAN_Cloud2Clear: 0.3165, loss_GAN_Clear2Cloud: 0.3353, loss_cycle_CloudClearCloud: 0.4390, loss_cycle_ClearCloudClear: 0.4438, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.4805, loss_pix_Clear: 0.0449
# using curriculum gan
# Epoch [1/60], Batch [80/450], loss_D: 0.2309, loss_G: 0.5805
# loss_GAN_Cloud2Clear: 0.5456, loss_GAN_Clear2Cloud: 0.3835, loss_cycle_CloudClearCloud: 0.4540, loss_cycle_ClearCloudClear: 0.4813, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.4910, loss_pix_Clear: 0.0495
# using curriculum gan
# Epoch [1/60], Batch [81/450], loss_D: 0.1273, loss_G: 0.2624
# loss_GAN_Cloud2Clear: 0.0328, loss_GAN_Clear2Cloud: 0.2534, loss_cycle_CloudClearCloud: 0.4789, loss_cycle_ClearCloudClear: 0.4572, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.5145, loss_pix_Clear: 0.0367
# using curriculum gan
# Epoch [1/60], Batch [82/450], loss_D: 0.3328, loss_G: 0.2678
# loss_GAN_Cloud2Clear: 0.0069, loss_GAN_Clear2Cloud: 0.2795, loss_cycle_CloudClearCloud: 0.5683, loss_cycle_ClearCloudClear: 0.4347, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.5950, loss_pix_Clear: 0.0356
# using curriculum gan
# Epoch [1/60], Batch [83/450], loss_D: 0.1453, loss_G: 0.4684
# loss_GAN_Cloud2Clear: 0.3252, loss_GAN_Clear2Cloud: 0.3187, loss_cycle_CloudClearCloud: 0.5656, loss_cycle_ClearCloudClear: 0.6789, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.5908, loss_pix_Clear: 0.0564
# using curriculum gan
# Epoch [1/60], Batch [84/450], loss_D: 0.1335, loss_G: 0.3600
# loss_GAN_Cloud2Clear: 0.4111, loss_GAN_Clear2Cloud: 0.0900, loss_cycle_CloudClearCloud: 0.4561, loss_cycle_ClearCloudClear: 0.4179, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.4834, loss_pix_Clear: 0.0310
# using curriculum gan
# Epoch [1/60], Batch [85/450], loss_D: 0.0898, loss_G: 0.2767
# loss_GAN_Cloud2Clear: 0.0537, loss_GAN_Clear2Cloud: 0.2623, loss_cycle_CloudClearCloud: 0.5211, loss_cycle_ClearCloudClear: 0.4760, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.5471, loss_pix_Clear: 0.0394
# using curriculum gan
# Epoch [1/60], Batch [86/450], loss_D: 0.2960, loss_G: 0.1971
# loss_GAN_Cloud2Clear: 0.0141, loss_GAN_Clear2Cloud: 0.1470, loss_cycle_CloudClearCloud: 0.5201, loss_cycle_ClearCloudClear: 0.4183, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.5470, loss_pix_Clear: 0.0267
# using curriculum gan
# Epoch [1/60], Batch [87/450], loss_D: 0.1976, loss_G: 0.5707
# loss_GAN_Cloud2Clear: 0.4309, loss_GAN_Clear2Cloud: 0.4930, loss_cycle_CloudClearCloud: 0.4671, loss_cycle_ClearCloudClear: 0.4421, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.4939, loss_pix_Clear: 0.0268
# using curriculum gan
# Epoch [1/60], Batch [88/450], loss_D: 0.2313, loss_G: 0.5153
# loss_GAN_Cloud2Clear: 0.2676, loss_GAN_Clear2Cloud: 0.5244, loss_cycle_CloudClearCloud: 0.4384, loss_cycle_ClearCloudClear: 0.5667, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.4640, loss_pix_Clear: 0.0348
# using curriculum gan
# Epoch [1/60], Batch [89/450], loss_D: 0.3121, loss_G: 0.1849
# loss_GAN_Cloud2Clear: 0.0966, loss_GAN_Clear2Cloud: 0.0236, loss_cycle_CloudClearCloud: 0.6008, loss_cycle_ClearCloudClear: 0.4178, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.6183, loss_pix_Clear: 0.0259
# using curriculum gan
# Epoch [1/60], Batch [90/450], loss_D: 0.1711, loss_G: 0.5056
# loss_GAN_Cloud2Clear: 0.4822, loss_GAN_Clear2Cloud: 0.2850, loss_cycle_CloudClearCloud: 0.5388, loss_cycle_ClearCloudClear: 0.5152, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.5649, loss_pix_Clear: 0.0270
# using curriculum gan
# Epoch [1/60], Batch [91/450], loss_D: 0.1489, loss_G: 0.5327
# loss_GAN_Cloud2Clear: 0.1894, loss_GAN_Clear2Cloud: 0.6022, loss_cycle_CloudClearCloud: 0.5855, loss_cycle_ClearCloudClear: 0.5924, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.6044, loss_pix_Clear: 0.0235
# using curriculum gan
# Epoch [1/60], Batch [92/450], loss_D: 0.1708, loss_G: 0.3438
# loss_GAN_Cloud2Clear: 0.0305, loss_GAN_Clear2Cloud: 0.4167, loss_cycle_CloudClearCloud: 0.4448, loss_cycle_ClearCloudClear: 0.5456, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.4633, loss_pix_Clear: 0.0345
# using curriculum gan
# Epoch [1/60], Batch [93/450], loss_D: 0.4967, loss_G: 0.1257
# loss_GAN_Cloud2Clear: 0.0131, loss_GAN_Clear2Cloud: 0.0278, loss_cycle_CloudClearCloud: 0.4254, loss_cycle_ClearCloudClear: 0.4131, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.4443, loss_pix_Clear: 0.0223
# using curriculum gan
# Epoch [1/60], Batch [94/450], loss_D: 0.2929, loss_G: 0.3748
# loss_GAN_Cloud2Clear: 0.4796, loss_GAN_Clear2Cloud: 0.0125, loss_cycle_CloudClearCloud: 0.4842, loss_cycle_ClearCloudClear: 0.5770, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.4991, loss_pix_Clear: 0.0253
# using curriculum gan
# Epoch [1/60], Batch [95/450], loss_D: 0.3109, loss_G: 0.8594
# loss_GAN_Cloud2Clear: 0.4396, loss_GAN_Clear2Cloud: 1.0152, loss_cycle_CloudClearCloud: 0.5929, loss_cycle_ClearCloudClear: 0.5810, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.6108, loss_pix_Clear: 0.0339
# using curriculum gan
# Epoch [1/60], Batch [96/450], loss_D: 0.2239, loss_G: 0.5302
# loss_GAN_Cloud2Clear: 0.3498, loss_GAN_Clear2Cloud: 0.5131, loss_cycle_CloudClearCloud: 0.4197, loss_cycle_ClearCloudClear: 0.4170, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.4319, loss_pix_Clear: 0.0250
# using curriculum gan
# Epoch [1/60], Batch [97/450], loss_D: 0.2253, loss_G: 0.2475
# loss_GAN_Cloud2Clear: 0.1580, loss_GAN_Clear2Cloud: 0.0958, loss_cycle_CloudClearCloud: 0.5832, loss_cycle_ClearCloudClear: 0.4181, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.5991, loss_pix_Clear: 0.0222
# using curriculum gan
# Epoch [1/60], Batch [98/450], loss_D: 0.1729, loss_G: 0.3456
# loss_GAN_Cloud2Clear: 0.3385, loss_GAN_Clear2Cloud: 0.0985, loss_cycle_CloudClearCloud: 0.5432, loss_cycle_ClearCloudClear: 0.5434, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.5544, loss_pix_Clear: 0.0299
# using curriculum gan
# Epoch [1/60], Batch [99/450], loss_D: 0.2416, loss_G: 0.4822
# loss_GAN_Cloud2Clear: 0.2035, loss_GAN_Clear2Cloud: 0.5632, loss_cycle_CloudClearCloud: 0.4208, loss_cycle_ClearCloudClear: 0.4088, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.4321, loss_pix_Clear: 0.0217
# using curriculum gan
# Epoch [1/60], Batch [100/450], loss_D: 0.1877, loss_G: 0.4837
# loss_GAN_Cloud2Clear: 0.2524, loss_GAN_Clear2Cloud: 0.4603, loss_cycle_CloudClearCloud: 0.5468, loss_cycle_ClearCloudClear: 0.5650, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.5625, loss_pix_Clear: 0.0324
# using curriculum gan
# Epoch [1/60], Batch [101/450], loss_D: 0.2667, loss_G: 0.3025
# loss_GAN_Cloud2Clear: 0.1096, loss_GAN_Clear2Cloud: 0.2586, loss_cycle_CloudClearCloud: 0.4409, loss_cycle_ClearCloudClear: 0.5587, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.4540, loss_pix_Clear: 0.0223
# using curriculum gan
# Epoch [1/60], Batch [102/450], loss_D: 0.0788, loss_G: 0.2481
# loss_GAN_Cloud2Clear: 0.2190, loss_GAN_Clear2Cloud: 0.0838, loss_cycle_CloudClearCloud: 0.4397, loss_cycle_ClearCloudClear: 0.3620, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.4497, loss_pix_Clear: 0.0223
# using curriculum gan
# Epoch [1/60], Batch [103/450], loss_D: 0.1827, loss_G: 0.2305
# loss_GAN_Cloud2Clear: 0.1637, loss_GAN_Clear2Cloud: 0.0924, loss_cycle_CloudClearCloud: 0.4224, loss_cycle_ClearCloudClear: 0.4328, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.4371, loss_pix_Clear: 0.0269
# using curriculum gan
# Epoch [1/60], Batch [104/450], loss_D: 0.1955, loss_G: 0.2763
# loss_GAN_Cloud2Clear: 0.0900, loss_GAN_Clear2Cloud: 0.2774, loss_cycle_CloudClearCloud: 0.3988, loss_cycle_ClearCloudClear: 0.3778, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.4131, loss_pix_Clear: 0.0214
# using curriculum gan
# Epoch [1/60], Batch [105/450], loss_D: 0.1574, loss_G: 0.3081
# loss_GAN_Cloud2Clear: 0.0292, loss_GAN_Clear2Cloud: 0.3298, loss_cycle_CloudClearCloud: 0.5394, loss_cycle_ClearCloudClear: 0.5755, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.5539, loss_pix_Clear: 0.0323
# using curriculum gan
# Epoch [1/60], Batch [106/450], loss_D: 0.1925, loss_G: 0.2130
# loss_GAN_Cloud2Clear: 0.0013, loss_GAN_Clear2Cloud: 0.1692, loss_cycle_CloudClearCloud: 0.5030, loss_cycle_ClearCloudClear: 0.6132, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.5164, loss_pix_Clear: 0.0336
# using curriculum gan
# Epoch [1/60], Batch [107/450], loss_D: 0.2385, loss_G: 0.2726
# loss_GAN_Cloud2Clear: 0.0950, loss_GAN_Clear2Cloud: 0.2301, loss_cycle_CloudClearCloud: 0.5022, loss_cycle_ClearCloudClear: 0.4280, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.5136, loss_pix_Clear: 0.0323
# using curriculum gan
# Epoch [1/60], Batch [108/450], loss_D: 0.2449, loss_G: 0.4009
# loss_GAN_Cloud2Clear: 0.3012, loss_GAN_Clear2Cloud: 0.3262, loss_cycle_CloudClearCloud: 0.3983, loss_cycle_ClearCloudClear: 0.3375, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.4059, loss_pix_Clear: 0.0228
# using curriculum gan
# Epoch [1/60], Batch [109/450], loss_D: 0.2935, loss_G: 0.2980
# loss_GAN_Cloud2Clear: 0.1476, loss_GAN_Clear2Cloud: 0.2095, loss_cycle_CloudClearCloud: 0.3344, loss_cycle_ClearCloudClear: 0.7101, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.3436, loss_pix_Clear: 0.0278
# using curriculum gan
# Epoch [1/60], Batch [110/450], loss_D: 0.2659, loss_G: 0.2258
# loss_GAN_Cloud2Clear: 0.0810, loss_GAN_Clear2Cloud: 0.1744, loss_cycle_CloudClearCloud: 0.4568, loss_cycle_ClearCloudClear: 0.3642, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.4679, loss_pix_Clear: 0.0251
# using curriculum gan
# Epoch [1/60], Batch [111/450], loss_D: 0.2372, loss_G: 0.4705
# loss_GAN_Cloud2Clear: 0.4437, loss_GAN_Clear2Cloud: 0.2840, loss_cycle_CloudClearCloud: 0.4507, loss_cycle_ClearCloudClear: 0.4854, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.4628, loss_pix_Clear: 0.0208
# using curriculum gan
# Epoch [1/60], Batch [112/450], loss_D: 0.2486, loss_G: 0.3969
# loss_GAN_Cloud2Clear: 0.3249, loss_GAN_Clear2Cloud: 0.2606, loss_cycle_CloudClearCloud: 0.3964, loss_cycle_ClearCloudClear: 0.4982, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.4085, loss_pix_Clear: 0.0228
# using curriculum gan
# Epoch [1/60], Batch [113/450], loss_D: 0.1622, loss_G: 0.3502
# loss_GAN_Cloud2Clear: 0.2447, loss_GAN_Clear2Cloud: 0.2429, loss_cycle_CloudClearCloud: 0.3578, loss_cycle_ClearCloudClear: 0.5658, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.3682, loss_pix_Clear: 0.0335
# using curriculum gan
# ...
# using curriculum gan
# Epoch [1/60], Batch [337/450], loss_D: 0.1348, loss_G: 0.5436
# loss_GAN_Cloud2Clear: 0.4475, loss_GAN_Clear2Cloud: 0.4277, loss_cycle_CloudClearCloud: 0.5079, loss_cycle_ClearCloudClear: 0.4220, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.4963, loss_pix_Clear: 0.0531
# using curriculum gan
# Epoch [1/60], Batch [338/450], loss_D: 0.0989, loss_G: 0.4616
# loss_GAN_Cloud2Clear: 0.3987, loss_GAN_Clear2Cloud: 0.3312, loss_cycle_CloudClearCloud: 0.4926, loss_cycle_ClearCloudClear: 0.3521, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.4874, loss_pix_Clear: 0.0439
# using curriculum gan
# Epoch [1/60], Batch [339/450], loss_D: 0.2795, loss_G: 0.6190
# loss_GAN_Cloud2Clear: 0.2692, loss_GAN_Clear2Cloud: 0.7749, loss_cycle_CloudClearCloud: 0.3809, loss_cycle_ClearCloudClear: 0.4757, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.3889, loss_pix_Clear: 0.0560
# using curriculum gan
# Epoch [1/60], Batch [340/450], loss_D: 0.1315, loss_G: 0.3311
# loss_GAN_Cloud2Clear: 0.2183, loss_GAN_Clear2Cloud: 0.2532, loss_cycle_CloudClearCloud: 0.4438, loss_cycle_ClearCloudClear: 0.3637, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.4326, loss_pix_Clear: 0.0411
# using curriculum gan
# Epoch [1/60], Batch [341/450], loss_D: 0.2136, loss_G: 0.3220
# loss_GAN_Cloud2Clear: 0.2417, loss_GAN_Clear2Cloud: 0.2241, loss_cycle_CloudClearCloud: 0.3717, loss_cycle_ClearCloudClear: 0.3776, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.3848, loss_pix_Clear: 0.0418
# using curriculum gan
# Epoch [1/60], Batch [342/450], loss_D: 0.2092, loss_G: 0.2238
# loss_GAN_Cloud2Clear: 0.1490, loss_GAN_Clear2Cloud: 0.0532, loss_cycle_CloudClearCloud: 0.4498, loss_cycle_ClearCloudClear: 0.5970, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.4538, loss_pix_Clear: 0.0605
# using curriculum gan
# Epoch [1/60], Batch [343/450], loss_D: 0.2378, loss_G: 0.4630
# loss_GAN_Cloud2Clear: 0.2190, loss_GAN_Clear2Cloud: 0.5130, loss_cycle_CloudClearCloud: 0.3735, loss_cycle_ClearCloudClear: 0.4502, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.3907, loss_pix_Clear: 0.0553
# using curriculum gan
# Epoch [1/60], Batch [344/450], loss_D: 0.0925, loss_G: 0.5121
# loss_GAN_Cloud2Clear: 0.1823, loss_GAN_Clear2Cloud: 0.5470, loss_cycle_CloudClearCloud: 0.7254, loss_cycle_ClearCloudClear: 0.5792, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.7585, loss_pix_Clear: 0.0505
# using curriculum gan
# Epoch [1/60], Batch [345/450], loss_D: 0.1521, loss_G: 0.3945
# loss_GAN_Cloud2Clear: 0.2100, loss_GAN_Clear2Cloud: 0.3973, loss_cycle_CloudClearCloud: 0.4206, loss_cycle_ClearCloudClear: 0.3340, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.4068, loss_pix_Clear: 0.0454
# using curriculum gan
# Epoch [1/60], Batch [346/450], loss_D: 0.3054, loss_G: 0.1660
# loss_GAN_Cloud2Clear: 0.0176, loss_GAN_Clear2Cloud: 0.0771, loss_cycle_CloudClearCloud: 0.3869, loss_cycle_ClearCloudClear: 0.6136, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.4019, loss_pix_Clear: 0.0339
# using curriculum gan
# Epoch [1/60], Batch [347/450], loss_D: 0.1604, loss_G: 0.4580
# loss_GAN_Cloud2Clear: 0.4584, loss_GAN_Clear2Cloud: 0.2405, loss_cycle_CloudClearCloud: 0.3930, loss_cycle_ClearCloudClear: 0.5468, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.3987, loss_pix_Clear: 0.0465
# using curriculum gan
# Epoch [1/60], Batch [348/450], loss_D: 0.2534, loss_G: 0.8024
# loss_GAN_Cloud2Clear: 0.9856, loss_GAN_Clear2Cloud: 0.4219, loss_cycle_CloudClearCloud: 0.5362, loss_cycle_ClearCloudClear: 0.3447, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.5674, loss_pix_Clear: 0.0347
# using curriculum gan
# Epoch [1/60], Batch [349/450], loss_D: 0.1248, loss_G: 0.6212
# loss_GAN_Cloud2Clear: 0.5691, loss_GAN_Clear2Cloud: 0.4156, loss_cycle_CloudClearCloud: 0.7173, loss_cycle_ClearCloudClear: 0.4257, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.7485, loss_pix_Clear: 0.0542
# using curriculum gan
# Epoch [1/60], Batch [350/450], loss_D: 0.1150, loss_G: 0.4795
# loss_GAN_Cloud2Clear: 0.4362, loss_GAN_Clear2Cloud: 0.2781, loss_cycle_CloudClearCloud: 0.4390, loss_cycle_ClearCloudClear: 0.6692, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.4570, loss_pix_Clear: 0.0266
# using curriculum gan
# Epoch [1/60], Batch [351/450], loss_D: 0.0887, loss_G: 0.7015
# loss_GAN_Cloud2Clear: 0.5535, loss_GAN_Clear2Cloud: 0.6176, loss_cycle_CloudClearCloud: 0.5786, loss_cycle_ClearCloudClear: 0.4713, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.5559, loss_pix_Clear: 0.0400
# using curriculum gan
# Epoch [1/60], Batch [352/450], loss_D: 0.1984, loss_G: 0.4774
# loss_GAN_Cloud2Clear: 0.2397, loss_GAN_Clear2Cloud: 0.4938, loss_cycle_CloudClearCloud: 0.5043, loss_cycle_ClearCloudClear: 0.4788, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.4929, loss_pix_Clear: 0.0412
# using curriculum gan
# Epoch [1/60], Batch [353/450], loss_D: 0.1140, loss_G: 0.4622
# loss_GAN_Cloud2Clear: 0.3294, loss_GAN_Clear2Cloud: 0.3501, loss_cycle_CloudClearCloud: 0.6518, loss_cycle_ClearCloudClear: 0.4206, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.6806, loss_pix_Clear: 0.0339
# using curriculum gan
# Epoch [1/60], Batch [354/450], loss_D: 0.2739, loss_G: 0.4123
# loss_GAN_Cloud2Clear: 0.2799, loss_GAN_Clear2Cloud: 0.3010, loss_cycle_CloudClearCloud: 0.4419, loss_cycle_ClearCloudClear: 0.6394, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.4521, loss_pix_Clear: 0.0478
# using curriculum gan
# Epoch [1/60], Batch [355/450], loss_D: 0.1565, loss_G: 0.3956
# loss_GAN_Cloud2Clear: 0.2788, loss_GAN_Clear2Cloud: 0.3216, loss_cycle_CloudClearCloud: 0.3937, loss_cycle_ClearCloudClear: 0.4251, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.4019, loss_pix_Clear: 0.0489
# using curriculum gan
# Epoch [1/60], Batch [356/450], loss_D: 0.1550, loss_G: 0.3953
# loss_GAN_Cloud2Clear: 0.4599, loss_GAN_Clear2Cloud: 0.1163, loss_cycle_CloudClearCloud: 0.4510, loss_cycle_ClearCloudClear: 0.4701, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.4709, loss_pix_Clear: 0.0460
# using curriculum gan
# Epoch [1/60], Batch [357/450], loss_D: 0.2357, loss_G: 0.3212
# loss_GAN_Cloud2Clear: 0.3959, loss_GAN_Clear2Cloud: 0.0628, loss_cycle_CloudClearCloud: 0.4194, loss_cycle_ClearCloudClear: 0.3616, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.4425, loss_pix_Clear: 0.0392
# using curriculum gan
# Epoch [1/60], Batch [358/450], loss_D: 0.0965, loss_G: 0.6393
# loss_GAN_Cloud2Clear: 0.5753, loss_GAN_Clear2Cloud: 0.4755, loss_cycle_CloudClearCloud: 0.6423, loss_cycle_ClearCloudClear: 0.3705, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.6763, loss_pix_Clear: 0.0400
# using curriculum gan
# Epoch [1/60], Batch [359/450], loss_D: 0.1207, loss_G: 0.5838
# loss_GAN_Cloud2Clear: 0.5752, loss_GAN_Clear2Cloud: 0.3488, loss_cycle_CloudClearCloud: 0.5097, loss_cycle_ClearCloudClear: 0.6004, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.5123, loss_pix_Clear: 0.0460
# using curriculum gan
# Epoch [1/60], Batch [360/450], loss_D: 0.1423, loss_G: 0.8388
# loss_GAN_Cloud2Clear: 0.8983, loss_GAN_Clear2Cloud: 0.5182, loss_cycle_CloudClearCloud: 0.5982, loss_cycle_ClearCloudClear: 0.5932, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.6212, loss_pix_Clear: 0.0465
# using curriculum gan
# Epoch [1/60], Batch [361/450], loss_D: 0.0782, loss_G: 0.3978
# loss_GAN_Cloud2Clear: 0.2781, loss_GAN_Clear2Cloud: 0.2752, loss_cycle_CloudClearCloud: 0.5948, loss_cycle_ClearCloudClear: 0.4521, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.6124, loss_pix_Clear: 0.0535
# using curriculum gan
# Epoch [1/60], Batch [362/450], loss_D: 0.1867, loss_G: 0.3490
# loss_GAN_Cloud2Clear: 0.1697, loss_GAN_Clear2Cloud: 0.2945, loss_cycle_CloudClearCloud: 0.5300, loss_cycle_ClearCloudClear: 0.4430, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.5305, loss_pix_Clear: 0.0452
# using curriculum gan
# Epoch [1/60], Batch [363/450], loss_D: 0.1583, loss_G: 0.6082
# loss_GAN_Cloud2Clear: 0.5081, loss_GAN_Clear2Cloud: 0.4912, loss_cycle_CloudClearCloud: 0.4656, loss_cycle_ClearCloudClear: 0.4383, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.4736, loss_pix_Clear: 0.0546
# using curriculum gan
# Epoch [1/60], Batch [364/450], loss_D: 0.1790, loss_G: 0.5204
# loss_GAN_Cloud2Clear: 0.4608, loss_GAN_Clear2Cloud: 0.3600, loss_cycle_CloudClearCloud: 0.4500, loss_cycle_ClearCloudClear: 0.4985, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.4585, loss_pix_Clear: 0.0547
# using curriculum gan
# Epoch [1/60], Batch [365/450], loss_D: 0.1913, loss_G: 0.5795
# loss_GAN_Cloud2Clear: 0.8461, loss_GAN_Clear2Cloud: 0.0359, loss_cycle_CloudClearCloud: 0.5654, loss_cycle_ClearCloudClear: 0.6628, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.5650, loss_pix_Clear: 0.0719
# using curriculum gan
# Epoch [1/60], Batch [366/450], loss_D: 0.1585, loss_G: 0.9133
# loss_GAN_Cloud2Clear: 1.2534, loss_GAN_Clear2Cloud: 0.3291, loss_cycle_CloudClearCloud: 0.6426, loss_cycle_ClearCloudClear: 0.4713, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.6461, loss_pix_Clear: 0.0504
# using curriculum gan
# Epoch [1/60], Batch [367/450], loss_D: 0.1834, loss_G: 0.5214
# loss_GAN_Cloud2Clear: 0.3112, loss_GAN_Clear2Cloud: 0.4713, loss_cycle_CloudClearCloud: 0.5560, loss_cycle_ClearCloudClear: 0.6022, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.5663, loss_pix_Clear: 0.0599
# using curriculum gan
# Epoch [1/60], Batch [368/450], loss_D: 0.1489, loss_G: 0.4176
# loss_GAN_Cloud2Clear: 0.3021, loss_GAN_Clear2Cloud: 0.2397, loss_cycle_CloudClearCloud: 0.6344, loss_cycle_ClearCloudClear: 0.6814, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.6312, loss_pix_Clear: 0.0533
# using curriculum gan
# Epoch [1/60], Batch [369/450], loss_D: 0.1144, loss_G: 0.6624
# loss_GAN_Cloud2Clear: 0.6610, loss_GAN_Clear2Cloud: 0.3419, loss_cycle_CloudClearCloud: 0.7313, loss_cycle_ClearCloudClear: 0.7426, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.7411, loss_pix_Clear: 0.0420
# using curriculum gan
# Epoch [1/60], Batch [370/450], loss_D: 0.1806, loss_G: 0.5423
# loss_GAN_Cloud2Clear: 0.6601, loss_GAN_Clear2Cloud: 0.1086, loss_cycle_CloudClearCloud: 0.6651, loss_cycle_ClearCloudClear: 0.7652, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.6762, loss_pix_Clear: 0.0599
# using curriculum gan
# Epoch [1/60], Batch [371/450], loss_D: 0.2666, loss_G: 0.4912
# loss_GAN_Cloud2Clear: 0.5162, loss_GAN_Clear2Cloud: 0.1320, loss_cycle_CloudClearCloud: 0.6925, loss_cycle_ClearCloudClear: 0.8281, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.7002, loss_pix_Clear: 0.0347
# using curriculum gan
# Epoch [1/60], Batch [372/450], loss_D: 0.1952, loss_G: 0.3049
# loss_GAN_Cloud2Clear: 0.2082, loss_GAN_Clear2Cloud: 0.0956, loss_cycle_CloudClearCloud: 0.6939, loss_cycle_ClearCloudClear: 0.6638, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.7178, loss_pix_Clear: 0.0550
# using curriculum gan
# Epoch [1/60], Batch [373/450], loss_D: 0.1638, loss_G: 0.4071
# loss_GAN_Cloud2Clear: 0.0375, loss_GAN_Clear2Cloud: 0.4509, loss_cycle_CloudClearCloud: 0.6974, loss_cycle_ClearCloudClear: 0.7587, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.7264, loss_pix_Clear: 0.0854
# using curriculum gan
# Epoch [1/60], Batch [374/450], loss_D: 0.1785, loss_G: 0.2373
# loss_GAN_Cloud2Clear: 0.0047, loss_GAN_Clear2Cloud: 0.1420, loss_cycle_CloudClearCloud: 0.7825, loss_cycle_ClearCloudClear: 0.6646, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.8062, loss_pix_Clear: 0.0666
# using curriculum gan
# Epoch [1/60], Batch [375/450], loss_D: 0.1173, loss_G: 0.2649
# loss_GAN_Cloud2Clear: 0.1099, loss_GAN_Clear2Cloud: 0.0964, loss_cycle_CloudClearCloud: 0.6117, loss_cycle_ClearCloudClear: 0.8280, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.6233, loss_pix_Clear: 0.0343
# using curriculum gan
# Epoch [1/60], Batch [376/450], loss_D: 0.3111, loss_G: 0.2492
# loss_GAN_Cloud2Clear: 0.1195, loss_GAN_Clear2Cloud: 0.1253, loss_cycle_CloudClearCloud: 0.5260, loss_cycle_ClearCloudClear: 0.5762, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.5468, loss_pix_Clear: 0.0514
# using curriculum gan
# Epoch [1/60], Batch [377/450], loss_D: 0.2025, loss_G: 0.2978
# loss_GAN_Cloud2Clear: 0.1103, loss_GAN_Clear2Cloud: 0.1626, loss_cycle_CloudClearCloud: 0.5868, loss_cycle_ClearCloudClear: 0.8479, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.6090, loss_pix_Clear: 0.0339
# using curriculum gan
# Epoch [1/60], Batch [378/450], loss_D: 0.1034, loss_G: 0.3102
# loss_GAN_Cloud2Clear: 0.0130, loss_GAN_Clear2Cloud: 0.3391, loss_cycle_CloudClearCloud: 0.5738, loss_cycle_ClearCloudClear: 0.5885, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.5819, loss_pix_Clear: 0.0529
# using curriculum gan
# Epoch [1/60], Batch [379/450], loss_D: 0.3051, loss_G: 0.3100
# loss_GAN_Cloud2Clear: 0.0446, loss_GAN_Clear2Cloud: 0.3071, loss_cycle_CloudClearCloud: 0.5489, loss_cycle_ClearCloudClear: 0.6116, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.5711, loss_pix_Clear: 0.0542
# using curriculum gan
# Epoch [1/60], Batch [380/450], loss_D: 0.2399, loss_G: 0.3057
# loss_GAN_Cloud2Clear: 0.1838, loss_GAN_Clear2Cloud: 0.1482, loss_cycle_CloudClearCloud: 0.6053, loss_cycle_ClearCloudClear: 0.5917, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.6343, loss_pix_Clear: 0.0566
# using curriculum gan
# Epoch [1/60], Batch [381/450], loss_D: 0.2388, loss_G: 0.3818
# loss_GAN_Cloud2Clear: 0.2955, loss_GAN_Clear2Cloud: 0.2061, loss_cycle_CloudClearCloud: 0.5402, loss_cycle_ClearCloudClear: 0.5778, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.5486, loss_pix_Clear: 0.0697
# using curriculum gan
# Epoch [1/60], Batch [382/450], loss_D: 0.1910, loss_G: 0.4368
# loss_GAN_Cloud2Clear: 0.4099, loss_GAN_Clear2Cloud: 0.1856, loss_cycle_CloudClearCloud: 0.5996, loss_cycle_ClearCloudClear: 0.6004, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.6162, loss_pix_Clear: 0.0481
# using curriculum gan
# Epoch [1/60], Batch [383/450], loss_D: 0.2298, loss_G: 0.5010
# loss_GAN_Cloud2Clear: 0.4460, loss_GAN_Clear2Cloud: 0.2913, loss_cycle_CloudClearCloud: 0.5739, loss_cycle_ClearCloudClear: 0.5878, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.5829, loss_pix_Clear: 0.0460
# using curriculum gan
# Epoch [1/60], Batch [384/450], loss_D: 0.0822, loss_G: 0.3285
# loss_GAN_Cloud2Clear: 0.0834, loss_GAN_Clear2Cloud: 0.3116, loss_cycle_CloudClearCloud: 0.5711, loss_cycle_ClearCloudClear: 0.5771, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.5698, loss_pix_Clear: 0.0455
# using curriculum gan
# Epoch [1/60], Batch [385/450], loss_D: 0.1845, loss_G: 0.3807
# loss_GAN_Cloud2Clear: 0.0979, loss_GAN_Clear2Cloud: 0.4188, loss_cycle_CloudClearCloud: 0.4921, loss_cycle_ClearCloudClear: 0.5811, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.5041, loss_pix_Clear: 0.0502
# using curriculum gan
# Epoch [1/60], Batch [386/450], loss_D: 0.2746, loss_G: 0.2470
# loss_GAN_Cloud2Clear: 0.0777, loss_GAN_Clear2Cloud: 0.1154, loss_cycle_CloudClearCloud: 0.5954, loss_cycle_ClearCloudClear: 0.7307, loss_identity_Cloud: 0.0000, loss_identity_Clear: 0.0000, loss_pix_Cloud: 0.6057, loss_pix_Clear: 0.0305
